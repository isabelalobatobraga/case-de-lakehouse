-- %% [markdown]
-- # Data Transformation – Gold Layer
-- ## dim_currency
--
-- This notebook performs the **dimensional modeling transformations** that populate the **gold layer**, generating **business-ready tables** such as dimensions and fact tables in **Delta Lake** format.

-- %%
CREATE OR REPLACE TABLE gold.take_home_test.dim_currency (
    currency_sk       BIGINT GENERATED ALWAYS AS IDENTITY,
    currency_code     STRING,
    currency_name     STRING,
    symbol            STRING,
    inserted_at       TIMESTAMP
);

-- %%
INSERT INTO gold.take_home_test.dim_currency (
    currency_code, currency_name, symbol, inserted_at
)
VALUES (
    'BRL',
    'Brazilian Real',
    'R$',
    current_timestamp()
);
