-- %% [markdown]
-- # Data Transformation – Gold Layer
-- ## dim_product
--
-- This notebook performs the **dimensional modeling transformations** that populate the **gold layer**, generating **business-ready tables** such as dimensions and fact tables in **Delta Lake** format.

-- %%
CREATE OR REPLACE TABLE gold.take_home_test.dim_product (
    product_sk       BIGINT GENERATED ALWAYS AS IDENTITY,
    product_name     STRING,
    product_category STRING,
    inserted_at      TIMESTAMP
);

-- %%
INSERT INTO gold.take_home_test.dim_product (
    product_name, product_category, inserted_at
)
VALUES (
    "Financial Transaction",
    'Core Banking',
    current_timestamp()
);
