-- %%
SELECT COUNT(*)
FROM bronze.take_home_test.pix_movements

-- %%
SELECT
    id,
    COUNT(*) AS qty
FROM bronze.take_home_test.pix_movements
GROUP BY id
HAVING COUNT(*) > 1;

-- %%
SELECT * 
FROM bronze.take_home_test.pix_movements
WHERE id = '969586077064732544'

-- %%
SELECT *
FROM bronze.take_home_test.pix_movements
LIMIT 20

-- %%
SELECT DISTINCT status
FROM bronze.take_home_test.pix_movements

-- %%
SELECT DISTINCT in_or_out
FROM bronze.take_home_test.pix_movements

-- %%
SELECT *
FROM bronze.take_home_test.pix_movements
WHERE status = "failed" and pix_completed_at IS NOT NULL

-- %%
SELECT
    id,
    COUNT(*) AS qty_rows,
    COUNT(DISTINCT pix_completed_at) AS distinct_completed_values
FROM bronze.take_home_test.pix_movements
GROUP BY id
HAVING COUNT(DISTINCT pix_completed_at) > 1;
