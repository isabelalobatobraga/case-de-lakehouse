-- %%
SELECT *
FROM bronze.take_home_test.country
LIMIT 10

-- %%
SELECT *
FROM bronze.take_home_test.city
LIMIT 10

-- %%
SELECT *
FROM bronze.take_home_test.state
LIMIT 10

-- %%
SELECT s.state_id
FROM bronze.take_home_test.state s
LEFT JOIN bronze.take_home_test.country c
    ON s.country_id = c.country_id
WHERE c.country_id IS NULL;
